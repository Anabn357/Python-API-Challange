# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as stats
# from scipy.stats import linregress
import datetime
import json
# Import API key
from api_keys import weather_api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1750)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1750)
lat_lngs = zip(lats, lngs)
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 715

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
count = 0
city_names = []
clouds = []
countries = []
dates = []
humidities = []
latitudes = []
longitudes = []
max_temps = []
wind_speeds = []
for city in cities:
    try:
        query = f"{base_url}appid={weather_api_key}&units={units}&q="
        response = requests.get(query + city).json()
        count = count + 1
        print(f"Processing Record {count} | {city}")
        country = response["sys"]["country"]
        latitude = response["coord"]["lat"]
        longitude = response["coord"]["lon"]
        date = response["dt"]
        temp = 1.8*(response["main"]["temp_max"]) + 32
        humidity = response["main"]["humidity"]
        cloudiness = response["clouds"]["all"]
        wind_speed = 2.236936*(response["wind"]["speed"])
        city_names.append(city)
        latitudes.append(latitude)
        longitudes.append(longitude)
        countries.append(country)
        dates.append(date)
        max_temps.append(temp)
        humidities.append(humidity)
        clouds.append(cloudiness)
        wind_speeds.append(wind_speed)
        
    except KeyError:
        print("Couldn't locate data. Skipping city!")
           
weather_data = {"City": city_names,
                "Cloudiness": clouds,
                "Country": countries,
                "Date": dates,
                "Humidity": humidities,
                "Lat": latitudes,
                "Lng": longitudes,
                "Max Temp": max_temps,
                "Wind Speeds": wind_speeds}
weather_reports = pd.DataFrame(weather_data)
weather_reports[["Max Temp", "Wind Speeds"]] = weather_reports[["Max Temp", "Wind Speeds"]].apply(pd.to_numeric)
weather_reports["Max Temp"] = weather_reports["Max Temp"].map("{:.2f}".format)
weather_reports["Wind Speeds"] = weather_reports["Wind Speeds"].map("{:.2f}".format)
weather_reports
# Out:
# Processing Record 1 | atuona
# Processing Record 2 | shambu
# Processing Record 3 | dengzhou
# Processing Record 4 | punta arenas
# Processing Record 5 | sfantu gheorghe
# Processing Record 6 | katsuura
# Processing Record 7 | praia
# Processing Record 8 | bredasdorp
# Processing Record 9 | bluff
# Processing Record 10 | illoqqortoormiut
# Couldn't locate data. Skipping city!
# Processing Record 11 | saint simons
# Processing Record 12 | wulanhaote
# Couldn't locate data. Skipping city!
# Processing Record 13 | kattivakkam
# Processing Record 14 | hambantota
# Processing Record 15 | ambilobe
# Processing Record 16 | kodiak
# Processing Record 17 | beloomut
# Processing Record 18 | ushuaia
# Processing Record 19 | hokitika
# Processing Record 20 | port hedland
# Processing Record 21 | macas
# Processing Record 22 | bambous virieux
# Processing Record 23 | castro
# Processing Record 24 | arkhipo-osipovka
# Processing Record 25 | mataura
# Processing Record 26 | luderitz
# Processing Record 27 | barentsburg
# Couldn't locate data. Skipping city!
# Processing Record 28 | provideniya
# Processing Record 29 | lagoa
# Processing Record 30 | bintulu
# Processing Record 31 | lasa
# Processing Record 32 | birjand
# Processing Record 33 | victoria
# Processing Record 34 | jamestown
# Processing Record 35 | gondar
# Processing Record 36 | norman wells
# Processing Record 37 | saint-augustin
# Processing Record 38 | new norfolk
# Processing Record 39 | beringovskiy
# Processing Record 40 | pareora
# Processing Record 41 | hermanus
# Processing Record 42 | papetoai
# Processing Record 43 | pevek
# Processing Record 44 | busselton
# Processing Record 45 | hobart
# Processing Record 46 | fortuna
# Processing Record 47 | vila franca do campo
# Processing Record 48 | kavieng
# Processing Record 49 | aswan
# Processing Record 50 | saskylakh
# Processing Record 51 | sentyabrskiy
# Couldn't locate data. Skipping city!
# Processing Record 52 | taolanaro
# Couldn't locate data. Skipping city!
# Processing Record 53 | bonthe
# Processing Record 54 | tucupita
# Processing Record 55 | avarua
# Processing Record 56 | puerto ayora
# Processing Record 57 | los llanos de aridane
# Processing Record 58 | kavaratti
# Processing Record 59 | rio de jesus
# Processing Record 60 | ust-ishim
# Processing Record 61 | tuktoyaktuk
# Processing Record 62 | port alfred
# Processing Record 63 | ancud
# Processing Record 64 | liverpool
# Processing Record 65 | cherskiy
# Processing Record 66 | faanui
# Processing Record 67 | dikson
# Processing Record 68 | saldanha
# Processing Record 69 | kokopo
# Processing Record 70 | phonhong
# Processing Record 71 | vaini
# Processing Record 72 | souillac
# Processing Record 73 | san patricio
# Processing Record 74 | qaqortoq
# Processing Record 75 | vaitupu
# Couldn't locate data. Skipping city!
# Processing Record 76 | sitka
# Processing Record 77 | kapaa
# Processing Record 78 | rawson
# Processing Record 79 | mitsamiouli
# Processing Record 80 | mahebourg
# Processing Record 81 | georgetown
# Processing Record 82 | tumannyy
# Couldn't locate data. Skipping city!
# Processing Record 83 | rikitea
# Processing Record 84 | okhotsk
# Processing Record 85 | aden
# Processing Record 86 | lorengau
# Processing Record 87 | grand river south east
# Couldn't locate data. Skipping city!
# Processing Record 88 | svinninge
# Processing Record 89 | quang ngai
# Processing Record 90 | tres lagoas
# Processing Record 91 | atar
# Processing Record 92 | hithadhoo
# Processing Record 93 | severnoye
# Processing Record 94 | cam ranh
# Processing Record 95 | butaritari
# Processing Record 96 | lebu
# Processing Record 97 | hovd
# Processing Record 98 | port lincoln
# Processing Record 99 | jatai
# Processing Record 100 | minab
# Processing Record 101 | traverse city
# Processing Record 102 | tsihombe
# Couldn't locate data. Skipping city!
# Processing Record 103 | freeport
# Processing Record 104 | dunedin
# Processing Record 105 | farafangana
# Processing Record 106 | sechura
# Processing Record 107 | seoul
# Processing Record 108 | tasiilaq
# Processing Record 109 | tiksi
# Processing Record 110 | valdez
# Processing Record 111 | lubben
# Processing Record 112 | thinadhoo
# Processing Record 113 | qaanaaq
# Processing Record 114 | segezha
# Processing Record 115 | sao filipe
# Processing Record 116 | barcelos
# Processing Record 117 | loreto
# Processing Record 118 | boa vista
# Processing Record 119 | isangel
# Processing Record 120 | crotone
# Processing Record 121 | guelengdeng
# Couldn't locate data. Skipping city!
# Processing Record 122 | torbay
# Processing Record 123 | chuy
# Processing Record 124 | shangzhi
# Processing Record 125 | don benito
# Processing Record 126 | caravelas
# Processing Record 127 | richards bay
# Processing Record 128 | mar del plata
# Processing Record 129 | te anau
# Processing Record 130 | kaitangata
# Processing Record 131 | yellowknife
# Processing Record 132 | mentok
# Couldn't locate data. Skipping city!
# Processing Record 133 | inhambane
# Processing Record 134 | lumsden
# Processing Record 135 | tautira
# Processing Record 136 | berlevag
# Processing Record 137 | aljezur
# Processing Record 138 | ponta do sol
# Processing Record 139 | paucartambo
# Couldn't locate data. Skipping city!
# Processing Record 140 | batemans bay
# Processing Record 141 | vila velha
# Processing Record 142 | tuatapere
# Processing Record 143 | port macquarie
# Processing Record 144 | el alto
# Processing Record 145 | brokopondo
# Processing Record 146 | tabiauea
# Couldn't locate data. Skipping city!
# Processing Record 147 | port elizabeth
# Processing Record 148 | bac lieu
# Processing Record 149 | kurilsk
# Processing Record 150 | qingyuan
# Processing Record 151 | barrow
# Processing Record 152 | bengkulu
# Processing Record 153 | albany
# Processing Record 154 | shumikha
# Processing Record 155 | pimentel
# Processing Record 156 | mount gambier
# Processing Record 157 | manggar
# Processing Record 158 | warqla
# Couldn't locate data. Skipping city!
# Processing Record 159 | cruzeiro do sul
# Processing Record 160 | chernyshevskiy
# Processing Record 161 | upernavik
# Processing Record 162 | cape town
# Processing Record 163 | nakamura
# Processing Record 164 | azul
# Processing Record 165 | cabo san lucas
# Processing Record 166 | pekan
# Processing Record 167 | monrovia
# Processing Record 168 | geraldton
# Processing Record 169 | komsomolskiy
# Processing Record 170 | kloulklubed
# Processing Record 171 | college
# Processing Record 172 | mudgee
# Processing Record 173 | oriximina
# Processing Record 174 | jardim
# Processing Record 175 | ladysmith
# Processing Record 176 | touros
# Processing Record 177 | valparaiso
# Processing Record 178 | belmonte
# Processing Record 179 | lompoc
# Processing Record 180 | leningradskiy
# Processing Record 181 | malm
# Processing Record 182 | san quintin
# Processing Record 183 | grootfontein
# Processing Record 184 | paamiut
# Processing Record 185 | xining
# Processing Record 186 | kargil
# Processing Record 187 | belushya guba
# Couldn't locate data. Skipping city!
# Processing Record 188 | mitu
# Processing Record 189 | amderma
# Couldn't locate data. Skipping city!
# Processing Record 190 | saleaula
# Couldn't locate data. Skipping city!
# Processing Record 191 | khonuu
# Couldn't locate data. Skipping city!
# Processing Record 192 | attawapiskat
# Couldn't locate data. Skipping city!
# Processing Record 193 | saint-philippe
# Processing Record 194 | rehli
# Processing Record 195 | jega
# Processing Record 196 | kudahuvadhoo
# Processing Record 197 | orlik
# Processing Record 198 | faya
# Processing Record 199 | longyearbyen
# Processing Record 200 | yar-sale
# Processing Record 201 | kamenka
# Processing Record 202 | beloha
# Processing Record 203 | santa cruz
# Processing Record 204 | omboue
# Processing Record 205 | asau
# Processing Record 206 | noumea
# Processing Record 207 | ahipara
# Processing Record 208 | namatanai
# Processing Record 209 | chapais
# Processing Record 210 | san jose
# Processing Record 211 | carnarvon
# Processing Record 212 | ardakan
# Processing Record 213 | udalguri
# Processing Record 214 | asyut
# Processing Record 215 | fort wellington
# Processing Record 216 | baykit
# Processing Record 217 | coruripe
# Processing Record 218 | luxor
# Processing Record 219 | klaksvik
# Processing Record 220 | samusu
# Couldn't locate data. Skipping city!
# Processing Record 221 | lagos
# Processing Record 222 | grindavik
# Processing Record 223 | cayenne
# Processing Record 224 | narasannapeta
# Processing Record 225 | rotenburg
# Processing Record 226 | envira
# Processing Record 227 | assomada
# Processing Record 228 | pisco
# Processing Record 229 | cidreira
# Processing Record 230 | shouguang
# Processing Record 231 | airai
# Processing Record 232 | biscarrosse
# Processing Record 233 | chokurdakh
# Processing Record 234 | linguere
# Processing Record 235 | zhangye
# Processing Record 236 | bethel
# Processing Record 237 | guerrero negro
# Processing Record 238 | karratha
# Processing Record 239 | sept-iles
# Processing Record 240 | jabinyanah
# Processing Record 241 | bougouni
# Processing Record 242 | guiratinga
# Processing Record 243 | mehamn
# Processing Record 244 | jinchang
# Processing Record 245 | zhanaozen
# Processing Record 246 | espinho
# Processing Record 247 | hue
# Processing Record 248 | stokmarknes
# Processing Record 249 | mnogovershinnyy
# Processing Record 250 | san matias
# Processing Record 251 | alofi
# Processing Record 252 | guangyuan
# Processing Record 253 | nikolaevo
# Processing Record 254 | loa janan
# Processing Record 255 | yerbogachen
# Processing Record 256 | turbat
# Processing Record 257 | cap malheureux
# Processing Record 258 | saint george
# Processing Record 259 | sikea
# Couldn't locate data. Skipping city!
# Processing Record 260 | viligili
# Couldn't locate data. Skipping city!
# Processing Record 261 | saint-pierre
# Processing Record 262 | saint-joseph
# Processing Record 263 | ust-kut
# Processing Record 264 | conakry
# Processing Record 265 | amga
# Processing Record 266 | yemtsa
# Processing Record 267 | nicoya
# Processing Record 268 | talcahuano
# Processing Record 269 | wageningen
# Processing Record 270 | hasaki
# Processing Record 271 | port victoria
# Processing Record 272 | biltine
# Processing Record 273 | maiduguri
# Processing Record 274 | thompson
# Processing Record 275 | phan thiet
# Processing Record 276 | christchurch
# Processing Record 277 | deming
# Processing Record 278 | gornopravdinsk
# Processing Record 279 | paoua
# Processing Record 280 | machilipatnam
# Processing Record 281 | viedma
# Processing Record 282 | nikolskoye
# Processing Record 283 | walvis bay
# Processing Record 284 | coihaique
# Processing Record 285 | santa barbara
# Processing Record 286 | labytnangi
# Processing Record 287 | pitimbu
# Processing Record 288 | tayu
# Processing Record 289 | zeya
# Processing Record 290 | los andes
# Processing Record 291 | batie
# Processing Record 292 | grand-santi
# Processing Record 293 | coahuayana
# Processing Record 294 | aki
# Processing Record 295 | trelew
# Processing Record 296 | rundu
# Processing Record 297 | fairbanks
# Processing Record 298 | saginaw
# Processing Record 299 | antsohihy
# Processing Record 300 | tabulbah
# Couldn't locate data. Skipping city!
# Processing Record 301 | nuuk
# Processing Record 302 | jalu
# Processing Record 303 | umzimvubu
# Couldn't locate data. Skipping city!
# Processing Record 304 | tilichiki
# Processing Record 305 | rapid valley
# Processing Record 306 | east london
# Processing Record 307 | coquimbo
# Processing Record 308 | talawdi
# Couldn't locate data. Skipping city!
# Processing Record 309 | kruisfontein
# Processing Record 310 | arecibo
# Processing Record 311 | prince rupert
# Processing Record 312 | olafsvik
# Processing Record 313 | puerto pinasco
# Couldn't locate data. Skipping city!
# Processing Record 314 | miajadas
# Processing Record 315 | gorontalo
# Processing Record 316 | ostrovnoy
# Processing Record 317 | griffith
# Processing Record 318 | zlatoustovsk
# Couldn't locate data. Skipping city!
# Processing Record 319 | pacific grove
# Processing Record 320 | nizwa
# Processing Record 321 | tongliao
# Processing Record 322 | broken hill
# Processing Record 323 | kharp
# Processing Record 324 | haines junction
# Processing Record 325 | sao felix do xingu
# Processing Record 326 | rabo de peixe
# Processing Record 327 | dingle
# Processing Record 328 | kyzyl-suu
# Processing Record 329 | barcelona
# Processing Record 330 | sebeta
# Processing Record 331 | khani
# Processing Record 332 | peleduy
# Processing Record 333 | umea
# Processing Record 334 | pemangkat
# Processing Record 335 | serebriya
# Processing Record 336 | rio tercero
# Processing Record 337 | yeehaw junction
# Couldn't locate data. Skipping city!
# Processing Record 338 | hailar
# Processing Record 339 | altay
# Processing Record 340 | cruzeiro do oeste
# Processing Record 341 | kefalos
# Processing Record 342 | hilo
# Processing Record 343 | lannion
# Processing Record 344 | san cristobal
# Processing Record 345 | narsaq
# Processing Record 346 | galgani
# Couldn't locate data. Skipping city!
# Processing Record 347 | louisbourg
# Couldn't locate data. Skipping city!
# Processing Record 348 | nokaneng
# Processing Record 349 | khash
# Processing Record 350 | kununurra
# Processing Record 351 | alugan
# Processing Record 352 | entre rios
# Processing Record 353 | rudnogorsk
# Processing Record 354 | buala
# Processing Record 355 | narnaund
# Processing Record 356 | bongandanga
# Processing Record 357 | surin
# Processing Record 358 | rawannawi
# Couldn't locate data. Skipping city!
# Processing Record 359 | jaguaruana
# Processing Record 360 | monroe
# Processing Record 361 | znamenskoye
# Processing Record 362 | shubarshi
# Processing Record 363 | balimo
# Couldn't locate data. Skipping city!
# Processing Record 364 | adrar
# Processing Record 365 | adelaide
# Processing Record 366 | surab
# Processing Record 367 | malangali
# Processing Record 368 | vardo
# Processing Record 369 | sorland
# Processing Record 370 | codrington
# Processing Record 371 | mayumba
# Processing Record 372 | bogorodskoye
# Processing Record 373 | tomioka
# Processing Record 374 | oussouye
# Processing Record 375 | ribeira grande
# Processing Record 376 | lata
# Processing Record 377 | najran
# Processing Record 378 | havoysund
# Processing Record 379 | fonte boa
# Processing Record 380 | pacasmayo
# Processing Record 381 | santa isabel do rio negro
# Processing Record 382 | tazovskiy
# Processing Record 383 | lavrentiya
# Processing Record 384 | arraial do cabo
# Processing Record 385 | biggar
# Processing Record 386 | tete
# Processing Record 387 | honningsvag
# Processing Record 388 | areka
# Processing Record 389 | gap
# Processing Record 390 | bilokurakyne
# Processing Record 391 | sorong
# Processing Record 392 | marystown
# Processing Record 393 | namibe
# Processing Record 394 | alice springs
# Processing Record 395 | hervey bay
# Processing Record 396 | zyryanka
# Processing Record 397 | netrakona
# Processing Record 398 | andros town
# Processing Record 399 | mazara del vallo
# Processing Record 400 | lere
# Processing Record 401 | porto novo
# Processing Record 402 | tucurui
# Processing Record 403 | lillooet
# Processing Record 404 | teahupoo
# Processing Record 405 | kohlu
# Processing Record 406 | vieste
# Processing Record 407 | borovichi
# Processing Record 408 | yagodnoye
# Processing Record 409 | wanning
# Processing Record 410 | horconcitos
# Processing Record 411 | filadelfia
# Processing Record 412 | egvekinot
# Processing Record 413 | pyinmana
# Processing Record 414 | at-bashi
# Processing Record 415 | selikhino
# Processing Record 416 | kamphaeng phet
# Processing Record 417 | solnechnyy
# Processing Record 418 | mishawaka
# Processing Record 419 | severo-kurilsk
# Processing Record 420 | khatanga
# Processing Record 421 | eregli
# Processing Record 422 | mezen
# Processing Record 423 | chateau-gontier
# Processing Record 424 | sibolga
# Processing Record 425 | north platte
# Processing Record 426 | gaoyou
# Processing Record 427 | zhigansk
# Processing Record 428 | hamilton
# Processing Record 429 | huambo
# Processing Record 430 | longlac
# Couldn't locate data. Skipping city!
# Processing Record 431 | padang
# Processing Record 432 | nizhneyansk
# Couldn't locate data. Skipping city!
# Processing Record 433 | deer lake
# Processing Record 434 | itarantim
# Processing Record 435 | urumqi
# Processing Record 436 | ngunguru
# Processing Record 437 | yaguajay
# Processing Record 438 | yulara
# Processing Record 439 | iqaluit
# Processing Record 440 | abu samrah
# Processing Record 441 | barsovo
# Processing Record 442 | palmer
# Processing Record 443 | yashkino
# Processing Record 444 | sibu
# Processing Record 445 | timbiras
# Processing Record 446 | buraydah
# Processing Record 447 | nantucket
# Processing Record 448 | port augusta
# Processing Record 449 | talnakh
# Processing Record 450 | kahului
# Processing Record 451 | fuerte olimpo
# Processing Record 452 | saint anthony
# Processing Record 453 | matongo
# Processing Record 454 | sorvag
# Couldn't locate data. Skipping city!
# Processing Record 455 | half moon bay
# Processing Record 456 | nara
# Processing Record 457 | nome
# Processing Record 458 | axim
# Processing Record 459 | robore
# Processing Record 460 | turukhansk
# Processing Record 461 | tomatlan
# Processing Record 462 | busto arsizio
# Processing Record 463 | kholodnyy
# Processing Record 464 | sieu-magherus
# Processing Record 465 | svobodnyy
# Processing Record 466 | romny
# Processing Record 467 | port blair
# Processing Record 468 | gigmoto
# Processing Record 469 | marcona
# Couldn't locate data. Skipping city!
# Processing Record 470 | samarai
# Processing Record 471 | neuquen
# Processing Record 472 | hami
# Processing Record 473 | diamantino
# Processing Record 474 | hay river
# Processing Record 475 | puerto cortes
# Couldn't locate data. Skipping city!
# Processing Record 476 | yeppoon
# Processing Record 477 | brookings
# Processing Record 478 | matagami
# Processing Record 479 | puerto escondido
# Processing Record 480 | vetlanda
# Processing Record 481 | tremedal
# Processing Record 482 | dargaville
# Processing Record 483 | ribas do rio pardo
# Processing Record 484 | chifeng
# Processing Record 485 | peniche
# Processing Record 486 | moranbah
# Processing Record 487 | fomboni
# Processing Record 488 | bemidji
# Processing Record 489 | wajima
# Processing Record 490 | angoram
# Processing Record 491 | esperance
# Processing Record 492 | almaznyy
# Processing Record 493 | bandar-e lengeh
# Processing Record 494 | caala
# Processing Record 495 | la palma
# Processing Record 496 | reisterstown
# Processing Record 497 | yerofey pavlovich
# Processing Record 498 | tairua
# Processing Record 499 | kisangani
# Processing Record 500 | safaga
# Processing Record 501 | dhidhdhoo
# Processing Record 502 | pokhara
# Processing Record 503 | sur
# Processing Record 504 | chihuahua
# Processing Record 505 | tongchuan
# Processing Record 506 | balabac
# Processing Record 507 | banda aceh
# Processing Record 508 | muriwai beach
# Processing Record 509 | fort-shevchenko
# Processing Record 510 | karaul
# Couldn't locate data. Skipping city!
# Processing Record 511 | ocean city
# Processing Record 512 | itarema
# Processing Record 513 | bilibino
# Processing Record 514 | clyde river
# Processing Record 515 | charters towers
# Processing Record 516 | iquique
# Processing Record 517 | tashtyp
# Processing Record 518 | manaure
# Processing Record 519 | kentau
# Processing Record 520 | matamoros
# Processing Record 521 | suoyarvi
# Processing Record 522 | hirado
# Processing Record 523 | aripuana
# Processing Record 524 | roald
# Processing Record 525 | fort dix
# Processing Record 526 | srivardhan
# Processing Record 527 | japura
# Processing Record 528 | krasnoborsk
# Processing Record 529 | marawi
# Processing Record 530 | ayr
# Processing Record 531 | hualmay
# Processing Record 532 | cumaribo
# Couldn't locate data. Skipping city!
# Processing Record 533 | elizabeth city
# Processing Record 534 | lixourion
# Processing Record 535 | acarau
# Processing Record 536 | warwick
# Processing Record 537 | colares
# Processing Record 538 | tessalit
# Processing Record 539 | kosh-agach
# Processing Record 540 | constantine
# Processing Record 541 | gandu
# Processing Record 542 | saviese
# Processing Record 543 | auki
# Processing Record 544 | bereda
# Processing Record 545 | vao
# Processing Record 546 | kemijarvi
# Processing Record 547 | trofors
# Processing Record 548 | guarapari
# Processing Record 549 | cozumel
# Processing Record 550 | arman
# Processing Record 551 | mora
# Processing Record 552 | kindu
# Processing Record 553 | kysyl-syr
# Processing Record 554 | ilinskiy
# Processing Record 555 | kaeo
# Processing Record 556 | barbar
# Couldn't locate data. Skipping city!
# Processing Record 557 | aklavik
# Processing Record 558 | kayerkan
# Processing Record 559 | plettenberg bay
# Processing Record 560 | banyo
# Processing Record 561 | port hardy
# Processing Record 562 | haverfordwest
# Processing Record 563 | jutai
# Processing Record 564 | cam pha
# Couldn't locate data. Skipping city!
# Processing Record 565 | poum
# Processing Record 566 | sawakin
# Processing Record 567 | tokmak
# Processing Record 568 | champerico
# Processing Record 569 | zhezkazgan
# Processing Record 570 | loiza
# Processing Record 571 | urulga
# Couldn't locate data. Skipping city!
# Processing Record 572 | marsh harbour
# Processing Record 573 | san juan
# Processing Record 574 | tezu
# Processing Record 575 | lumding
# Processing Record 576 | zavetnoye
# Processing Record 577 | cayhagan
# Processing Record 578 | warnes
# Processing Record 579 | ewa beach
# Processing Record 580 | riyadh
# Processing Record 581 | jinxiang
# Processing Record 582 | ishigaki
# Processing Record 583 | koulamoutou
# Processing Record 584 | nador
# Processing Record 585 | hanzhong
# Processing Record 586 | amsterdam
# Processing Record 587 | nyrob
# Processing Record 588 | mogochin
# Couldn't locate data. Skipping city!
# Processing Record 589 | gizo
# Processing Record 590 | saint-leu
# Processing Record 591 | zabid
# Processing Record 592 | camopi
# Processing Record 593 | acajutla
# Processing Record 594 | gimbi
# Processing Record 595 | jalalpur
# Processing Record 596 | vestmannaeyjar
# Processing Record 597 | huilong
# Processing Record 598 | mys shmidta
# Couldn't locate data. Skipping city!
# Processing Record 599 | nishihara
# Processing Record 600 | dakar
# Processing Record 601 | amalapuram
# Processing Record 602 | normandin
# Processing Record 603 | maxixe
# Processing Record 604 | bubaque
# Processing Record 605 | chatellerault
# Processing Record 606 | auala
# Couldn't locate data. Skipping city!
# Processing Record 607 | layou
# Processing Record 608 | gold coast
# Processing Record 609 | bahir dar
# Processing Record 610 | motygino
# Processing Record 611 | malwan
# Couldn't locate data. Skipping city!
# Processing Record 612 | abu dhabi
# Processing Record 613 | san policarpo
# Processing Record 614 | moose factory
# Processing Record 615 | ayan
# Processing Record 616 | aquiraz
# Processing Record 617 | taoudenni
# Processing Record 618 | kailua
# Processing Record 619 | coromandel
# Processing Record 620 | ketchikan
# Processing Record 621 | kiri buru
# Processing Record 622 | saint augustine
# Processing Record 623 | rawah
# Processing Record 624 | abomsa
# Processing Record 625 | yarada
# Processing Record 626 | gao
# Processing Record 627 | biertan
# Processing Record 628 | anamur
# Processing Record 629 | morinville
# Processing Record 630 | tura
# Processing Record 631 | strezhevoy
# Processing Record 632 | dongsheng
# Processing Record 633 | mandalgovi
# Processing Record 634 | krasnoselkup
# Processing Record 635 | lolua
# Couldn't locate data. Skipping city!
# Processing Record 636 | bow island
# Processing Record 637 | kuningan
# Processing Record 638 | nouakchott
# Processing Record 639 | wanaka
# Processing Record 640 | shanghai
# Processing Record 641 | peyima
# Processing Record 642 | mocambique
# Couldn't locate data. Skipping city!
# Processing Record 643 | abu kamal
# Processing Record 644 | husavik
# Processing Record 645 | foam lake
# Processing Record 646 | voh
# Processing Record 647 | escarcega
# Processing Record 648 | khajuraho
# Processing Record 649 | ngukurr
# Couldn't locate data. Skipping city!
# Processing Record 650 | murgab
# Processing Record 651 | formoso do araguaia
# Couldn't locate data. Skipping city!
# Processing Record 652 | sa kaeo
# Processing Record 653 | paita
# Processing Record 654 | sapao
# Couldn't locate data. Skipping city!
# Processing Record 655 | lemesos
# Couldn't locate data. Skipping city!
# Processing Record 656 | kismayo
# Processing Record 657 | satitoa
# Couldn't locate data. Skipping city!
# Processing Record 658 | natal
# Processing Record 659 | dali
# Processing Record 660 | el badari
# Couldn't locate data. Skipping city!
# Processing Record 661 | nanortalik
# Processing Record 662 | zhoucheng
# Processing Record 663 | sergeyevka
# Processing Record 664 | kidal
# Processing Record 665 | vidim
# Processing Record 666 | san jeronimo
# Processing Record 667 | malinovka
# Processing Record 668 | stekolnyy
# Couldn't locate data. Skipping city!
# Processing Record 669 | labutta
# Couldn't locate data. Skipping city!
# Processing Record 670 | mwinilunga
# Processing Record 671 | athgarh
# Couldn't locate data. Skipping city!
# Processing Record 672 | kashan
# Processing Record 673 | teseney
# Processing Record 674 | sampit
# Processing Record 675 | severo-yeniseyskiy
# Processing Record 676 | san carlos
# Processing Record 677 | pingliang
# Processing Record 678 | stornoway
# Processing Record 679 | sioux lookout
# Processing Record 680 | platanos
# Processing Record 681 | harigue
# Couldn't locate data. Skipping city!
# Processing Record 682 | erzurum
# Processing Record 683 | malakal
# Processing Record 684 | antsirabe
# Processing Record 685 | bucerias
# Processing Record 686 | ostersund
# Processing Record 687 | kampene
# Processing Record 688 | riosucio
# Processing Record 689 | palabuhanratu
# Couldn't locate data. Skipping city!
# Processing Record 690 | todos santos
# Processing Record 691 | armenia
# Processing Record 692 | sharjah
# Processing Record 693 | imeni stepana razina
# Processing Record 694 | henties bay
# Processing Record 695 | olinda
# Processing Record 696 | lima
# Processing Record 697 | mosetse
# Processing Record 698 | zheleznodorozhnyy
# Processing Record 699 | yining
# Processing Record 700 | pindiga
# Processing Record 701 | rafsanjan
# Processing Record 702 | biak
# Processing Record 703 | verkhniye kigi
# Processing Record 704 | mayor pablo lagerenza
# Processing Record 705 | maceio
# Processing Record 706 | blonduos
# Couldn't locate data. Skipping city!
# Processing Record 707 | koslan
# Processing Record 708 | hare bay
# Processing Record 709 | necochea
# Processing Record 710 | isiro
# Processing Record 711 | buin
# Processing Record 712 | rovaniemi
# Processing Record 713 | zaraza
# Processing Record 714 | lahaina
# Processing Record 715 | maningrida
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0             atuona          31      PF  1592177223        76  -9.80 -139.03
# 1             shambu          83      ET  1592177223       100   9.57   37.10
# 2           dengzhou         100      CN  1592177223        33  37.81  120.75
# 3       punta arenas          90      CL  1592177223        86 -53.15  -70.92
# 4    sfantu gheorghe          97      RO  1592177223        91  45.87   25.78
# ..               ...         ...     ...         ...       ...    ...     ...
# 650             buin           0      CL  1592177318        51 -33.73  -70.75
# 651        rovaniemi          79      FI  1592177318        62  66.50   25.72
# 652           zaraza          47      VE  1592177318        80   9.35  -65.32
# 653          lahaina          40      US  1592177318        45  20.88 -156.68
# 654       maningrida           1      AU  1592177319        65 -12.07  134.27
#
#     Max Temp Wind Speeds
# 0      80.13       13.67
# 1      53.38        1.07
# 2      79.00        9.42
# 3      37.40       12.75
# 4      62.01        3.06
# ..       ...         ...
# 650    64.40        6.93
# 651    59.00       10.29
# 652    79.65        6.55
# 653    87.80       23.04
# 654    77.59       12.73
#
# [655 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_reports.to_csv("weather_reports.csv")
weather_reports.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           atuona          31      PF  1592177223        76  -9.80 -139.03
# 1           shambu          83      ET  1592177223       100   9.57   37.10
# 2         dengzhou         100      CN  1592177223        33  37.81  120.75
# 3     punta arenas          90      CL  1592177223        86 -53.15  -70.92
# 4  sfantu gheorghe          97      RO  1592177223        91  45.87   25.78
#
#   Max Temp Wind Speeds
# 0    80.13       13.67
# 1    53.38        1.07
# 2    79.00        9.42
# 3    37.40       12.75
# 4    62.01        3.06

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
converted_dates = []
for date in dates:
    converted_date = datetime.datetime.fromtimestamp(date).strftime("%m/%d/%Y")
    converted_dates.append(converted_date)
    
weather_reports["Converted Date"] = converted_dates
weather_reports = weather_reports[["City", 
                                   "Cloudiness", 
                                   "Country", 
                                   "Date", 
                                   "Converted Date", 
                                   "Humidity", 
                                   "Lat", 
                                   "Lng", 
                                   "Max Temp", 
                                   "Wind Speeds"]]
plot_date = weather_reports.loc[0, "Converted Date"]
plt.scatter(weather_reports["Lat"], weather_data["Max Temp"], facecolor="#66CDAA", edgecolor="black")
plt.title(f"City Latitude vs. Max Temperature ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.show()
print("The above scatter plot shows the relationship between the latitude of cities and their maximum temperatures, as recorded on June 14, 2020.")
# Out:
# The above scatter plot shows the relationship between the latitude of cities and their maximum temperatures, as recorded on June 14, 2020.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_reports["Lat"], weather_data["Humidity"], facecolor="#E3CF57", edgecolor="black")
plt.title(f"City Latitude vs. Humidity ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.show()
print("The above scatter plot shows the relationship between the latitude of cities and their humidity, as recorded on June 14, 2020.")
# Out:
# The above scatter plot shows the relationship between the latitude of cities and their humidity, as recorded on June 14, 2020.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_reports["Lat"], weather_data["Cloudiness"], facecolor="#838B8B", edgecolor="black")
plt.title(f"City Latitude vs. Humidity ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()
print("The above scatter plot shows the relationship between the latitude of cities and their cloudiness, as recorded on June 14, 2020.")
# Out:
# The above scatter plot shows the relationship between the latitude of cities and their cloudiness, as recorded on June 14, 2020.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_reports["Lat"], weather_data["Wind Speeds"], facecolor="#6495ED", edgecolor="black")
plt.title(f"City Latitude vs. Wind Speeds ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()
print("The above scatter plot shows the relationship between the latitude of cities and wind speeds, as recorded on June 14, 2020.")
# Out:
# The above scatter plot shows the relationship between the latitude of cities and wind speeds, as recorded on June 14, 2020.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames


# Northern DF
northern_df = weather_reports.loc[weather_reports["Lat"] > 0,:]
northern_df.head()
# Out:
#               City  Cloudiness Country        Date Converted Date  Humidity  \
# 1           shambu          83      ET  1592177223     06/14/2020       100
# 2         dengzhou         100      CN  1592177223     06/14/2020        33
# 4  sfantu gheorghe          97      RO  1592177223     06/14/2020        91
# 5         katsuura          96      JP  1592177223     06/14/2020        77
# 6            praia          11      CV  1592177223     06/14/2020        57
#
#      Lat     Lng Max Temp Wind Speeds
# 1   9.57   37.10    53.38        1.07
# 2  37.81  120.75    79.00        9.42
# 4  45.87   25.78    62.01        3.06
# 5  35.13  140.30    80.01       12.97
# 6  14.92  -23.51    80.60       12.75

# %%
# Southern DF
southern_df = weather_reports.loc[weather_reports["Lat"] < 0,:]
southern_df.head()
# Out:
#             City  Cloudiness Country        Date Converted Date  Humidity  \
# 0         atuona          31      PF  1592177223     06/14/2020        76
# 3   punta arenas          90      CL  1592177223     06/14/2020        86
# 7     bredasdorp          76      ZA  1592177224     06/14/2020        93
# 8          bluff         100      NZ  1592177224     06/14/2020        83
# 12      ambilobe          48      MG  1592177224     06/14/2020        63
#
#       Lat     Lng Max Temp Wind Speeds
# 0   -9.80 -139.03    80.13       13.67
# 3  -53.15  -70.92    37.40       12.75
# 7  -34.53   20.04    55.40        4.92
# 8  -46.60  168.33    39.00        3.00
# 12 -13.20   49.05    71.35        1.81

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = northern_df["Max Temp"].astype(float)
y_values = northern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(30,10),fontsize=15,color="red")

# Make Labels
plt.xlabel("Max Temp (F)")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = southern_df["Max Temp"].astype(float)
y_values = southern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(32,-5),fontsize=15,color="red")

# Make Labels
plt.xlabel("Max Temp (F)")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = northern_df["Humidity"].astype(float)
y_values = northern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(10,3),fontsize=15,color="red")

# Make Labels
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = southern_df["Humidity"].astype(float)
y_values = southern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(10,-55),fontsize=15,color="red")

# Make Labels
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = northern_df["Cloudiness"].astype(float)
y_values = northern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(20,75),fontsize=15,color="red")

# Make Labels
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = southern_df["Cloudiness"].astype(float)
y_values = southern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(20,-50),fontsize=15,color="red")

# Make Labels
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = northern_df["Wind Speeds"].astype(float)
y_values = northern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(25,30),fontsize=15,color="red")

# Make Labels
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = southern_df["Wind Speeds"].astype(float)
y_values = southern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(7,-43),fontsize=15,color="red")

# Make Labels
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.show()
