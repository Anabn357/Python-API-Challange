# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as stats
# from scipy.stats import linregress
import datetime
import json
# Import API key
from api_keys import weather_api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1750)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1750)
lat_lngs = zip(lats, lngs)
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 681

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
count = 0
city_names = []
clouds = []
countries = []
dates = []
humidities = []
latitudes = []
longitudes = []
max_temps = []
wind_speeds = []
for city in cities:
    try:
        query = f"{base_url}appid={weather_api_key}&units={units}&q="
        response = requests.get(query + city).json()
        count = count + 1
        print(f"Processing Record {count} | {city}")
        country = response["sys"]["country"]
        latitude = response["coord"]["lat"]
        longitude = response["coord"]["lon"]
        date = response["dt"]
        temp = 1.8*(response["main"]["temp_max"]) + 32
        humidity = response["main"]["humidity"]
        cloudiness = response["clouds"]["all"]
        wind_speed = 2.236936*(response["wind"]["speed"])
        city_names.append(city)
        latitudes.append(latitude)
        longitudes.append(longitude)
        countries.append(country)
        dates.append(date)
        max_temps.append(temp)
        humidities.append(humidity)
        clouds.append(cloudiness)
        wind_speeds.append(wind_speed)
        
    except KeyError:
        print("Couldn't locate data. Skipping city!")
           
weather_data = {"City": city_names,
                "Cloudiness": clouds,
                "Country": countries,
                "Date": dates,
                "Humidity": humidities,
                "Lat": latitudes,
                "Lng": longitudes,
                "Max Temp": max_temps,
                "Wind Speeds": wind_speeds}
weather_reports = pd.DataFrame(weather_data)
weather_reports[["Max Temp", "Wind Speeds"]] = weather_reports[["Max Temp", "Wind Speeds"]].apply(pd.to_numeric)
weather_reports["Max Temp"] = weather_reports["Max Temp"].map("{:.2f}".format)
weather_reports["Wind Speeds"] = weather_reports["Wind Speeds"].map("{:.2f}".format)
# Out:
# Processing Record 1 | saint-philippe
# Processing Record 2 | punta arenas
# Processing Record 3 | sentyabrskiy
# Couldn't locate data. Skipping city!
# Processing Record 4 | copiapo
# Processing Record 5 | avarua
# Processing Record 6 | karratha
# Processing Record 7 | severo-yeniseyskiy
# Processing Record 8 | albany
# Processing Record 9 | busselton
# Processing Record 10 | kapaa
# Processing Record 11 | santa fe
# Processing Record 12 | illoqqortoormiut
# Couldn't locate data. Skipping city!
# Processing Record 13 | georgetown
# Processing Record 14 | lagoa
# Processing Record 15 | kruisfontein
# Processing Record 16 | mataura
# Processing Record 17 | dwarka
# Processing Record 18 | cidreira
# Processing Record 19 | qaanaaq
# Processing Record 20 | ushuaia
# Processing Record 21 | coahuayana
# Processing Record 22 | svetlogorsk
# Processing Record 23 | bluff
# Processing Record 24 | bethel
# Processing Record 25 | roebourne
# Processing Record 26 | botshabelo
# Processing Record 27 | weligama
# Processing Record 28 | new norfolk
# Processing Record 29 | ola
# Processing Record 30 | jamestown
# Processing Record 31 | hay river
# Processing Record 32 | vaini
# Processing Record 33 | hilo
# Processing Record 34 | rikitea
# Processing Record 35 | kourou
# Processing Record 36 | armidale
# Processing Record 37 | wulanhaote
# Couldn't locate data. Skipping city!
# Processing Record 38 | hofn
# Processing Record 39 | tasiilaq
# Processing Record 40 | ribeira grande
# Processing Record 41 | isiro
# Processing Record 42 | bilibino
# Processing Record 43 | bredasdorp
# Processing Record 44 | atuona
# Processing Record 45 | pisco
# Processing Record 46 | southbridge
# Processing Record 47 | amderma
# Couldn't locate data. Skipping city!
# Processing Record 48 | columbus
# Processing Record 49 | airai
# Processing Record 50 | norman wells
# Processing Record 51 | hermanus
# Processing Record 52 | port alfred
# Processing Record 53 | portland
# Processing Record 54 | bratsk
# Processing Record 55 | tiksi
# Processing Record 56 | vostok
# Processing Record 57 | hualmay
# Processing Record 58 | bambous virieux
# Processing Record 59 | bad lippspringe
# Processing Record 60 | clyde river
# Processing Record 61 | artyom
# Processing Record 62 | cherskiy
# Processing Record 63 | yerbogachen
# Processing Record 64 | mount gambier
# Processing Record 65 | yialos
# Couldn't locate data. Skipping city!
# Processing Record 66 | ullapool
# Processing Record 67 | taolanaro
# Couldn't locate data. Skipping city!
# Processing Record 68 | severo-kurilsk
# Processing Record 69 | hobart
# Processing Record 70 | cape town
# Processing Record 71 | ilulissat
# Processing Record 72 | victoria
# Processing Record 73 | lebu
# Processing Record 74 | yellowknife
# Processing Record 75 | bengkulu
# Processing Record 76 | luderitz
# Processing Record 77 | barrow
# Processing Record 78 | saleaula
# Couldn't locate data. Skipping city!
# Processing Record 79 | castro
# Processing Record 80 | souillac
# Processing Record 81 | flinders
# Processing Record 82 | puerto ayora
# Processing Record 83 | elk city
# Processing Record 84 | luanda
# Processing Record 85 | uchiza
# Processing Record 86 | dubti
# Processing Record 87 | grand river south east
# Couldn't locate data. Skipping city!
# Processing Record 88 | carnarvon
# Processing Record 89 | sperkhias
# Couldn't locate data. Skipping city!
# Processing Record 90 | salalah
# Processing Record 91 | alekseyevsk
# Processing Record 92 | paulista
# Processing Record 93 | broken hill
# Processing Record 94 | fuxin
# Processing Record 95 | nha trang
# Processing Record 96 | port blair
# Processing Record 97 | lolua
# Couldn't locate data. Skipping city!
# Processing Record 98 | saldanha
# Processing Record 99 | fortuna
# Processing Record 100 | mehamn
# Processing Record 101 | ouro preto do oeste
# Processing Record 102 | tabiauea
# Couldn't locate data. Skipping city!
# Processing Record 103 | praia da vitoria
# Processing Record 104 | boyolangu
# Processing Record 105 | gandorhun
# Processing Record 106 | upernavik
# Processing Record 107 | mega
# Processing Record 108 | nikolskoye
# Processing Record 109 | burriana
# Processing Record 110 | salvador
# Processing Record 111 | maputo
# Processing Record 112 | chapais
# Processing Record 113 | marv dasht
# Couldn't locate data. Skipping city!
# Processing Record 114 | ojinaga
# Processing Record 115 | buluang
# Processing Record 116 | kuching
# Processing Record 117 | tsihombe
# Couldn't locate data. Skipping city!
# Processing Record 118 | barentsburg
# Couldn't locate data. Skipping city!
# Processing Record 119 | semporna
# Processing Record 120 | edd
# Processing Record 121 | hithadhoo
# Processing Record 122 | saint george
# Processing Record 123 | dikson
# Processing Record 124 | nishihara
# Processing Record 125 | port elizabeth
# Processing Record 126 | buchanan
# Processing Record 127 | taltal
# Processing Record 128 | divnomorskoye
# Processing Record 129 | cayenne
# Processing Record 130 | back mountain
# Processing Record 131 | tyukhtet
# Processing Record 132 | coos bay
# Processing Record 133 | saskylakh
# Processing Record 134 | grahamstown
# Processing Record 135 | victor harbor
# Processing Record 136 | kuytun
# Processing Record 137 | kaitangata
# Processing Record 138 | huarmey
# Processing Record 139 | vanavara
# Processing Record 140 | pozega
# Processing Record 141 | mahebourg
# Processing Record 142 | oranjemund
# Processing Record 143 | mys shmidta
# Couldn't locate data. Skipping city!
# Processing Record 144 | dinar
# Processing Record 145 | havoysund
# Processing Record 146 | rancho palos verdes
# Processing Record 147 | andenes
# Processing Record 148 | yeppoon
# Processing Record 149 | sidi ali
# Processing Record 150 | nizhneyansk
# Couldn't locate data. Skipping city!
# Processing Record 151 | bonanza
# Processing Record 152 | krasnoselkup
# Processing Record 153 | longyearbyen
# Processing Record 154 | cartagena
# Processing Record 155 | khatanga
# Processing Record 156 | beira
# Processing Record 157 | bathsheba
# Processing Record 158 | chuy
# Processing Record 159 | leningradskiy
# Processing Record 160 | torbay
# Processing Record 161 | provideniya
# Processing Record 162 | san vicente
# Processing Record 163 | colomi
# Processing Record 164 | sehithwa
# Processing Record 165 | kutum
# Processing Record 166 | batemans bay
# Processing Record 167 | lavrentiya
# Processing Record 168 | tambovka
# Processing Record 169 | eyl
# Processing Record 170 | alotau
# Couldn't locate data. Skipping city!
# Processing Record 171 | umm lajj
# Processing Record 172 | auki
# Processing Record 173 | arraial do cabo
# Processing Record 174 | tuktoyaktuk
# Processing Record 175 | san jeronimo
# Processing Record 176 | butaritari
# Processing Record 177 | belushya guba
# Couldn't locate data. Skipping city!
# Processing Record 178 | meulaboh
# Processing Record 179 | harper
# Processing Record 180 | merauke
# Processing Record 181 | ahipara
# Processing Record 182 | nicoya
# Processing Record 183 | ambon
# Processing Record 184 | tomatlan
# Processing Record 185 | javanrud
# Processing Record 186 | winnemucca
# Processing Record 187 | namibe
# Processing Record 188 | moravska trebova
# Processing Record 189 | lasa
# Processing Record 190 | champerico
# Processing Record 191 | iqaluit
# Processing Record 192 | moosomin
# Processing Record 193 | carutapera
# Processing Record 194 | khandagayty
# Processing Record 195 | tual
# Processing Record 196 | bondo
# Processing Record 197 | toboso
# Processing Record 198 | mackay
# Processing Record 199 | sosnovo-ozerskoye
# Processing Record 200 | sorvag
# Couldn't locate data. Skipping city!
# Processing Record 201 | bundibugyo
# Processing Record 202 | los llanos de aridane
# Processing Record 203 | margate
# Processing Record 204 | kodiak
# Processing Record 205 | turbat
# Processing Record 206 | attawapiskat
# Couldn't locate data. Skipping city!
# Processing Record 207 | east london
# Processing Record 208 | yekaterinovka
# Processing Record 209 | maniitsoq
# Processing Record 210 | peleduy
# Processing Record 211 | preobrazheniye
# Processing Record 212 | kuznechnoye
# Processing Record 213 | nguiu
# Couldn't locate data. Skipping city!
# Processing Record 214 | coquimbo
# Processing Record 215 | college
# Processing Record 216 | oriximina
# Processing Record 217 | tecoanapa
# Processing Record 218 | husavik
# Processing Record 219 | touros
# Processing Record 220 | eganville
# Processing Record 221 | haag
# Processing Record 222 | nyurba
# Processing Record 223 | la huerta
# Processing Record 224 | codrington
# Processing Record 225 | yutsa
# Processing Record 226 | lerwick
# Processing Record 227 | la reforma
# Processing Record 228 | axim
# Processing Record 229 | riaba
# Couldn't locate data. Skipping city!
# Processing Record 230 | beringovskiy
# Processing Record 231 | sao jose da coroa grande
# Processing Record 232 | leh
# Processing Record 233 | inhambane
# Processing Record 234 | gondanglegi
# Processing Record 235 | koungou
# Processing Record 236 | santa rosalia
# Processing Record 237 | port lincoln
# Processing Record 238 | bhachau
# Processing Record 239 | labrea
# Processing Record 240 | katsuura
# Processing Record 241 | port hardy
# Processing Record 242 | qaqortoq
# Processing Record 243 | pangnirtung
# Processing Record 244 | santa rosa
# Processing Record 245 | fairbanks
# Processing Record 246 | bolshaya rechka
# Processing Record 247 | arlit
# Processing Record 248 | martinopolis
# Processing Record 249 | wad madani
# Processing Record 250 | hami
# Processing Record 251 | kenai
# Processing Record 252 | geraldton
# Processing Record 253 | quatre cocos
# Processing Record 254 | tigil
# Processing Record 255 | laguna
# Processing Record 256 | dunedin
# Processing Record 257 | gorno-chuyskiy
# Couldn't locate data. Skipping city!
# Processing Record 258 | kawalu
# Processing Record 259 | nova olimpia
# Processing Record 260 | kloulklubed
# Processing Record 261 | khash
# Processing Record 262 | seddon
# Processing Record 263 | luau
# Processing Record 264 | narsaq
# Processing Record 265 | pangody
# Processing Record 266 | karaul
# Couldn't locate data. Skipping city!
# Processing Record 267 | beinamar
# Processing Record 268 | yar-sale
# Processing Record 269 | okha
# Processing Record 270 | thompson
# Processing Record 271 | jalu
# Processing Record 272 | tottori
# Processing Record 273 | chokurdakh
# Processing Record 274 | mill creek
# Processing Record 275 | chitral
# Processing Record 276 | faanui
# Processing Record 277 | kariba
# Processing Record 278 | bull savanna
# Processing Record 279 | shache
# Processing Record 280 | yarkovo
# Processing Record 281 | okhotsk
# Processing Record 282 | ivybridge
# Processing Record 283 | manggar
# Processing Record 284 | northam
# Processing Record 285 | sao joao da barra
# Processing Record 286 | severnoye
# Processing Record 287 | gazojak
# Processing Record 288 | talcahuano
# Processing Record 289 | hobe sound
# Processing Record 290 | mezen
# Processing Record 291 | carballo
# Processing Record 292 | constitucion
# Processing Record 293 | port said
# Processing Record 294 | kabansk
# Processing Record 295 | ostrovnoy
# Processing Record 296 | cockburn town
# Processing Record 297 | comodoro rivadavia
# Processing Record 298 | kahului
# Processing Record 299 | sheboygan
# Processing Record 300 | san jose
# Processing Record 301 | sampit
# Processing Record 302 | rawson
# Processing Record 303 | ayan
# Processing Record 304 | port-gentil
# Processing Record 305 | guerrero negro
# Processing Record 306 | nanortalik
# Processing Record 307 | jega
# Processing Record 308 | lac du bonnet
# Processing Record 309 | manjacaze
# Processing Record 310 | cairns
# Processing Record 311 | jaumave
# Processing Record 312 | volodarskiy
# Processing Record 313 | laukaa
# Processing Record 314 | kanniyakumari
# Processing Record 315 | pakwach
# Couldn't locate data. Skipping city!
# Processing Record 316 | beloha
# Processing Record 317 | salinas
# Processing Record 318 | mnogovershinnyy
# Processing Record 319 | riom
# Processing Record 320 | lorengau
# Processing Record 321 | kavaratti
# Processing Record 322 | muisne
# Processing Record 323 | faya
# Processing Record 324 | acuna
# Couldn't locate data. Skipping city!
# Processing Record 325 | kavieng
# Processing Record 326 | bolungarvik
# Couldn't locate data. Skipping city!
# Processing Record 327 | olafsvik
# Processing Record 328 | ginda
# Processing Record 329 | zhucheng
# Processing Record 330 | kaliningrad
# Processing Record 331 | mao
# Processing Record 332 | otradnoye
# Processing Record 333 | ratnagiri
# Processing Record 334 | esperance
# Processing Record 335 | lata
# Processing Record 336 | biu
# Processing Record 337 | dubbo
# Processing Record 338 | vaitupu
# Couldn't locate data. Skipping city!
# Processing Record 339 | tura
# Processing Record 340 | ocean city
# Processing Record 341 | san carlos
# Processing Record 342 | tuyen quang
# Processing Record 343 | soyaniquilpan
# Processing Record 344 | varhaug
# Processing Record 345 | elk point
# Processing Record 346 | fare
# Processing Record 347 | domna
# Processing Record 348 | ponta do sol
# Processing Record 349 | plettenberg bay
# Processing Record 350 | viedma
# Processing Record 351 | lubango
# Processing Record 352 | bonnyville
# Processing Record 353 | anahuac
# Processing Record 354 | waingapu
# Processing Record 355 | acari
# Processing Record 356 | klaksvik
# Processing Record 357 | aksu
# Processing Record 358 | butembo
# Processing Record 359 | samarai
# Processing Record 360 | hecun
# Processing Record 361 | cumpas
# Processing Record 362 | gat
# Processing Record 363 | caluquembe
# Processing Record 364 | grindavik
# Processing Record 365 | ewa beach
# Processing Record 366 | zaraza
# Processing Record 367 | henties bay
# Processing Record 368 | grand gaube
# Processing Record 369 | ternate
# Processing Record 370 | gazli
# Processing Record 371 | kaeng khoi
# Processing Record 372 | raga
# Processing Record 373 | itaituba
# Processing Record 374 | saint-francois
# Processing Record 375 | walvis bay
# Processing Record 376 | ostashkov
# Processing Record 377 | tekeli
# Processing Record 378 | ijaki
# Couldn't locate data. Skipping city!
# Processing Record 379 | tidore
# Couldn't locate data. Skipping city!
# Processing Record 380 | malacacheta
# Processing Record 381 | chlorakas
# Processing Record 382 | saint-ambroise
# Processing Record 383 | diego de almagro
# Processing Record 384 | bardiyah
# Processing Record 385 | yulara
# Processing Record 386 | ust-nera
# Processing Record 387 | agadir
# Processing Record 388 | mar del plata
# Processing Record 389 | te anau
# Processing Record 390 | bosaso
# Processing Record 391 | tumannyy
# Couldn't locate data. Skipping city!
# Processing Record 392 | road town
# Processing Record 393 | lebanon
# Processing Record 394 | sabha
# Processing Record 395 | kununurra
# Processing Record 396 | khani
# Processing Record 397 | namatanai
# Processing Record 398 | nizwa
# Processing Record 399 | dongsheng
# Processing Record 400 | tezu
# Processing Record 401 | sibolga
# Processing Record 402 | caranguejeira
# Processing Record 403 | rabo de peixe
# Processing Record 404 | el alto
# Processing Record 405 | sorland
# Processing Record 406 | sisimiut
# Processing Record 407 | manyana
# Processing Record 408 | canutama
# Processing Record 409 | pringsewu
# Processing Record 410 | suntar
# Processing Record 411 | ituni
# Couldn't locate data. Skipping city!
# Processing Record 412 | mubende
# Processing Record 413 | altamont
# Processing Record 414 | san policarpo
# Processing Record 415 | bubaque
# Processing Record 416 | shimoda
# Processing Record 417 | garowe
# Processing Record 418 | dabat
# Processing Record 419 | evensk
# Processing Record 420 | vanimo
# Processing Record 421 | cabo san lucas
# Processing Record 422 | deputatskiy
# Processing Record 423 | fort-shevchenko
# Processing Record 424 | kodinsk
# Processing Record 425 | hai phong
# Couldn't locate data. Skipping city!
# Processing Record 426 | vallenar
# Processing Record 427 | maldonado
# Processing Record 428 | atar
# Processing Record 429 | maceio
# Processing Record 430 | utiroa
# Couldn't locate data. Skipping city!
# Processing Record 431 | kabompo
# Processing Record 432 | taksimo
# Processing Record 433 | nelson bay
# Processing Record 434 | vilyuysk
# Processing Record 435 | hwange
# Processing Record 436 | sai buri
# Processing Record 437 | bakel
# Processing Record 438 | kimbe
# Processing Record 439 | nouadhibou
# Processing Record 440 | vardo
# Processing Record 441 | talnakh
# Processing Record 442 | rawah
# Processing Record 443 | mukhen
# Processing Record 444 | piranshahr
# Processing Record 445 | coihueco
# Processing Record 446 | port macquarie
# Processing Record 447 | pevek
# Processing Record 448 | tanout
# Processing Record 449 | algarrobo
# Processing Record 450 | san carlos de bariloche
# Processing Record 451 | sao gabriel da cachoeira
# Processing Record 452 | xuddur
# Processing Record 453 | kamenskoye
# Couldn't locate data. Skipping city!
# Processing Record 454 | sorong
# Processing Record 455 | aktash
# Processing Record 456 | khasan
# Processing Record 457 | sabang
# Processing Record 458 | abu jubayhah
# Couldn't locate data. Skipping city!
# Processing Record 459 | ruatoria
# Couldn't locate data. Skipping city!
# Processing Record 460 | palabuhanratu
# Couldn't locate data. Skipping city!
# Processing Record 461 | bereda
# Processing Record 462 | jumla
# Processing Record 463 | hobyo
# Processing Record 464 | emba
# Processing Record 465 | arosa
# Processing Record 466 | necochea
# Processing Record 467 | kragero
# Processing Record 468 | savinka
# Processing Record 469 | bonthe
# Processing Record 470 | gewane
# Processing Record 471 | mogadishu
# Processing Record 472 | paramonga
# Processing Record 473 | vestbygda
# Couldn't locate data. Skipping city!
# Processing Record 474 | sribne
# Processing Record 475 | general roca
# Processing Record 476 | sitka
# Processing Record 477 | ust-tsilma
# Processing Record 478 | sambava
# Processing Record 479 | labuhan
# Processing Record 480 | poum
# Processing Record 481 | le vauclin
# Processing Record 482 | dongying
# Processing Record 483 | cradock
# Processing Record 484 | manono
# Processing Record 485 | yumen
# Processing Record 486 | zalantun
# Processing Record 487 | nombre de dios
# Processing Record 488 | tuatapere
# Processing Record 489 | skalistyy
# Couldn't locate data. Skipping city!
# Processing Record 490 | sao filipe
# Processing Record 491 | rincon
# Processing Record 492 | santa barbara
# Processing Record 493 | turukhansk
# Processing Record 494 | yenagoa
# Processing Record 495 | barra patuca
# Processing Record 496 | bealanana
# Processing Record 497 | samusu
# Couldn't locate data. Skipping city!
# Processing Record 498 | jieshi
# Processing Record 499 | kurchanskaya
# Processing Record 500 | iskateley
# Processing Record 501 | saint anthony
# Processing Record 502 | srednekolymsk
# Processing Record 503 | san rafael
# Processing Record 504 | polyarnyy
# Processing Record 505 | miles city
# Processing Record 506 | conceicao do araguaia
# Processing Record 507 | marsh harbour
# Processing Record 508 | mafinga
# Processing Record 509 | koraput
# Processing Record 510 | maracas
# Processing Record 511 | cururupu
# Processing Record 512 | valle de allende
# Processing Record 513 | qeshm
# Processing Record 514 | padang
# Processing Record 515 | bayanday
# Processing Record 516 | montrose
# Processing Record 517 | richards bay
# Processing Record 518 | jos
# Processing Record 519 | guozhen
# Processing Record 520 | mormugao
# Processing Record 521 | giyani
# Processing Record 522 | apatou
# Processing Record 523 | novo aripuana
# Processing Record 524 | mentok
# Couldn't locate data. Skipping city!
# Processing Record 525 | saint-paul
# Processing Record 526 | ayagoz
# Processing Record 527 | banda aceh
# Processing Record 528 | caohe
# Processing Record 529 | abu kamal
# Processing Record 530 | althofen
# Processing Record 531 | mannargudi
# Processing Record 532 | pemba
# Processing Record 533 | haines junction
# Processing Record 534 | albina
# Processing Record 535 | linchuan
# Couldn't locate data. Skipping city!
# Processing Record 536 | san andres
# Processing Record 537 | oga
# Processing Record 538 | ellensburg
# Processing Record 539 | khairabad
# Processing Record 540 | anadyr
# Processing Record 541 | galesong
# Processing Record 542 | abalak
# Processing Record 543 | la primavera
# Processing Record 544 | sioux lookout
# Processing Record 545 | kupang
# Processing Record 546 | nipawin
# Processing Record 547 | zaragoza
# Processing Record 548 | buala
# Processing Record 549 | taldan
# Processing Record 550 | mount isa
# Processing Record 551 | marcona
# Couldn't locate data. Skipping city!
# Processing Record 552 | olinda
# Processing Record 553 | ouallam
# Processing Record 554 | ranau
# Processing Record 555 | dori
# Processing Record 556 | la brea
# Processing Record 557 | voi
# Processing Record 558 | arak
# Processing Record 559 | flin flon
# Processing Record 560 | makakilo city
# Processing Record 561 | da nang
# Processing Record 562 | butterworth
# Processing Record 563 | broome
# Processing Record 564 | muros
# Processing Record 565 | baykalsk
# Processing Record 566 | nagato
# Processing Record 567 | hambantota
# Processing Record 568 | bisalpur
# Processing Record 569 | kathmandu
# Processing Record 570 | riyadh
# Processing Record 571 | hasaki
# Processing Record 572 | hyeres
# Processing Record 573 | brigantine
# Processing Record 574 | clearlake
# Processing Record 575 | quepos
# Processing Record 576 | waipawa
# Processing Record 577 | ballina
# Processing Record 578 | kostino
# Processing Record 579 | virden
# Processing Record 580 | medina
# Processing Record 581 | jalapa
# Processing Record 582 | urusha
# Processing Record 583 | bell ville
# Processing Record 584 | mende
# Processing Record 585 | tiarei
# Processing Record 586 | olavarria
# Processing Record 587 | labutta
# Couldn't locate data. Skipping city!
# Processing Record 588 | katsina
# Processing Record 589 | sandpoint
# Processing Record 590 | bolondron
# Processing Record 591 | hargeysa
# Processing Record 592 | bilma
# Processing Record 593 | pacific grove
# Processing Record 594 | bloomington
# Processing Record 595 | envira
# Processing Record 596 | fort nelson
# Processing Record 597 | polunochnoye
# Processing Record 598 | avera
# Processing Record 599 | villa corzo
# Processing Record 600 | iracoubo
# Processing Record 601 | soria
# Processing Record 602 | portsmouth
# Processing Record 603 | mahibadhoo
# Processing Record 604 | hamilton
# Processing Record 605 | murakami
# Processing Record 606 | snyder
# Processing Record 607 | daru
# Processing Record 608 | palmer
# Processing Record 609 | pierrelatte
# Processing Record 610 | barra do garcas
# Processing Record 611 | vologda
# Processing Record 612 | san patricio
# Processing Record 613 | banmo
# Couldn't locate data. Skipping city!
# Processing Record 614 | tilichiki
# Processing Record 615 | mala
# Processing Record 616 | tunxi
# Couldn't locate data. Skipping city!
# Processing Record 617 | kytlym
# Couldn't locate data. Skipping city!
# Processing Record 618 | acajutla
# Processing Record 619 | santa cruz
# Processing Record 620 | madarounfa
# Processing Record 621 | carmen
# Processing Record 622 | thanh hoa
# Processing Record 623 | cooma
# Processing Record 624 | matara
# Processing Record 625 | rocha
# Processing Record 626 | newcastle
# Processing Record 627 | puerto ayacucho
# Processing Record 628 | naze
# Processing Record 629 | kalmunai
# Processing Record 630 | ngunguru
# Processing Record 631 | kuito
# Processing Record 632 | saurimo
# Processing Record 633 | geresk
# Couldn't locate data. Skipping city!
# Processing Record 634 | paso de los toros
# Processing Record 635 | bintulu
# Processing Record 636 | valparaiso
# Processing Record 637 | talara
# Processing Record 638 | mokshan
# Processing Record 639 | kargil
# Processing Record 640 | bom jardim
# Processing Record 641 | kangaatsiaq
# Processing Record 642 | saquisili
# Processing Record 643 | laramie
# Processing Record 644 | kedougou
# Processing Record 645 | itoman
# Processing Record 646 | negombo
# Processing Record 647 | antu
# Processing Record 648 | nemuro
# Processing Record 649 | camabatela
# Processing Record 650 | ukiah
# Processing Record 651 | uray
# Processing Record 652 | lucapa
# Processing Record 653 | mangan
# Processing Record 654 | talas
# Processing Record 655 | tupik
# Processing Record 656 | rosh pinna
# Processing Record 657 | montepuez
# Processing Record 658 | deh rawud
# Couldn't locate data. Skipping city!
# Processing Record 659 | linhares
# Processing Record 660 | talavera de la reina
# Processing Record 661 | gao
# Processing Record 662 | bongandanga
# Processing Record 663 | curup
# Processing Record 664 | aklavik
# Processing Record 665 | wangkui
# Processing Record 666 | atasu
# Processing Record 667 | george town
# Processing Record 668 | savannah bight
# Processing Record 669 | dingle
# Processing Record 670 | marsa matruh
# Processing Record 671 | lompoc
# Processing Record 672 | chicama
# Processing Record 673 | wajid
# Processing Record 674 | juifang
# Couldn't locate data. Skipping city!
# Processing Record 675 | obihiro
# Processing Record 676 | vangaindrano
# Processing Record 677 | siukh
# Processing Record 678 | meadow lake
# Processing Record 679 | ormara
# Processing Record 680 | ransang
# Processing Record 681 | neiafu

# %%
weather_reports.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  saint-philippe          71      RE  1592263379        82 -21.36   55.77
# 1    punta arenas          20      CL  1592263124        86 -53.15  -70.92
# 2         copiapo          91      CL  1592263304        76 -27.37  -70.33
# 3          avarua          25      CK  1592263380        53 -21.21 -159.78
# 4        karratha           0      AU  1592263380        40 -20.74  116.85
#
#   Max Temp Wind Speeds
# 0    68.00       11.41
# 1    37.40       11.41
# 2    57.20        6.93
# 3    75.20       11.41
# 4    67.62       16.08

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_reports.to_csv("weather_reports.csv")
weather_reports.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  saint-philippe          71      RE  1592263379        82 -21.36   55.77
# 1    punta arenas          20      CL  1592263124        86 -53.15  -70.92
# 2         copiapo          91      CL  1592263304        76 -27.37  -70.33
# 3          avarua          25      CK  1592263380        53 -21.21 -159.78
# 4        karratha           0      AU  1592263380        40 -20.74  116.85
#
#   Max Temp Wind Speeds
# 0    68.00       11.41
# 1    37.40       11.41
# 2    57.20        6.93
# 3    75.20       11.41
# 4    67.62       16.08

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
converted_dates = []
for date in dates:
    converted_date = datetime.datetime.fromtimestamp(date).strftime("%m/%d/%Y")
    converted_dates.append(converted_date)
    
weather_reports["Converted Date"] = converted_dates
weather_reports = weather_reports[["City", 
                                   "Cloudiness", 
                                   "Country", 
                                   "Date", 
                                   "Converted Date", 
                                   "Humidity", 
                                   "Lat", 
                                   "Lng", 
                                   "Max Temp", 
                                   "Wind Speeds"]]
plot_date = weather_reports.loc[0, "Converted Date"]
plt.scatter(weather_reports["Lat"], weather_data["Max Temp"], facecolor="#66CDAA", edgecolor="black")
plt.title(f"City Latitude vs. Max Temperature ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig('Images/figure_1.png', dpi=100)
plt.show()
print("The above scatter plot shows the relationship between the latitude of cities and their maximum temperatures, as recorded on June 14, 2020.")
# Out:
# The above scatter plot shows the relationship between the latitude of cities and their maximum temperatures, as recorded on June 14, 2020.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_reports["Lat"], weather_data["Humidity"], facecolor="#E3CF57", edgecolor="black")
plt.title(f"City Latitude vs. Humidity ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig('Images/figure_2.png', dpi=100)
plt.show()
print("The above scatter plot shows the relationship between the latitude of cities and their humidity, as recorded on June 14, 2020.")
# Out:
# The above scatter plot shows the relationship between the latitude of cities and their humidity, as recorded on June 14, 2020.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_reports["Lat"], weather_data["Cloudiness"], facecolor="#838B8B", edgecolor="black")
plt.title(f"City Latitude vs. Humidity ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig('Images/figure_3.png', dpi=100)
plt.show()
print("The above scatter plot shows the relationship between the latitude of cities and their cloudiness, as recorded on June 14, 2020.")
# Out:
# The above scatter plot shows the relationship between the latitude of cities and their cloudiness, as recorded on June 14, 2020.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_reports["Lat"], weather_data["Wind Speeds"], facecolor="#6495ED", edgecolor="black")
plt.title(f"City Latitude vs. Wind Speeds ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig('Images/figure_4.png', dpi=100)
plt.show()
print("The above scatter plot shows the relationship between the latitude of cities and wind speeds, as recorded on June 14, 2020.")
# Out:
# The above scatter plot shows the relationship between the latitude of cities and wind speeds, as recorded on June 14, 2020.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames


# Northern DF
northern_df = weather_reports.loc[weather_reports["Lat"] > 0,:]
northern_df.head()
# Out:
#                   City  Cloudiness Country        Date Converted Date  \
# 5   severo-yeniseyskiy          35      RU  1592263380     06/15/2020
# 6               albany          24      US  1592263380     06/15/2020
# 8                kapaa          20      US  1592263101     06/15/2020
# 10          georgetown          40      MY  1592263381     06/15/2020
# 11               lagoa          45      PT  1592263381     06/15/2020
#
#     Humidity    Lat     Lng Max Temp Wind Speeds
# 5         88  60.37   93.04    41.59        3.40
# 6         53  42.60  -73.97    75.00        2.84
# 8         62  22.08 -159.32    84.20       14.99
# 10        94   5.41  100.34    82.00        2.24
# 11        88  39.05  -27.98    64.09       18.25

# %%
# Southern DF
southern_df = weather_reports.loc[weather_reports["Lat"] < 0,:]
southern_df.head()
# Out:
#              City  Cloudiness Country        Date Converted Date  Humidity  \
# 0  saint-philippe          71      RE  1592263379     06/15/2020        82
# 1    punta arenas          20      CL  1592263124     06/15/2020        86
# 2         copiapo          91      CL  1592263304     06/15/2020        76
# 3          avarua          25      CK  1592263380     06/15/2020        53
# 4        karratha           0      AU  1592263380     06/15/2020        40
#
#      Lat     Lng Max Temp Wind Speeds
# 0 -21.36   55.77    68.00       11.41
# 1 -53.15  -70.92    37.40       11.41
# 2 -27.37  -70.33    57.20        6.93
# 3 -21.21 -159.78    75.20       11.41
# 4 -20.74  116.85    67.62       16.08

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = northern_df["Max Temp"].astype(float)
y_values = northern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(30,10),fontsize=15,color="red")

# Make Labels
plt.xlabel("Max Temp (F)")
plt.ylabel("Latitude")
plt.savefig('Images/figure_5.png', dpi=100)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = southern_df["Max Temp"].astype(float)
y_values = southern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(32,-5),fontsize=15,color="red")

# Make Labels
plt.xlabel("Max Temp (F)")
plt.ylabel("Latitude")
plt.savefig('Images/figure_6.png', dpi=100)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = northern_df["Humidity"].astype(float)
y_values = northern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(10,3),fontsize=15,color="red")

# Make Labels
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.savefig('Images/figure_7.png', dpi=100)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = southern_df["Humidity"].astype(float)
y_values = southern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(10,-55),fontsize=15,color="red")

# Make Labels
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.savefig('Images/figure_8.png', dpi=100)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = northern_df["Cloudiness"].astype(float)
y_values = northern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(20,75),fontsize=15,color="red")

# Make Labels
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.savefig('Images/figure_9.png', dpi=100)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = southern_df["Cloudiness"].astype(float)
y_values = southern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(20,-50),fontsize=15,color="red")

# Make Labels
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.savefig('Images/figure_10.png', dpi=100)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = northern_df["Wind Speeds"].astype(float)
y_values = northern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(25,30),fontsize=15,color="red")

# Make Labels
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.savefig('Images/figure_11.png', dpi=100)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = southern_df["Wind Speeds"].astype(float)
y_values = southern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(7,-43),fontsize=15,color="red")

# Make Labels
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.savefig('Images/figure_12.png', dpi=100)
plt.show()
